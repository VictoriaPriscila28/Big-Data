# %% [markdown]
# ### Urbanismo: Processos de Licenciamento Urbanístico na Cidade do Recife
# #### Dataset: Conjunto de Dados apresenta os processos de licenciamento urbanístico da cidade do Recife.
# Justificativa: O conjunto de dados sobre os processos de licenciamento urbanístico na cidade do Recife é uma escolha relevante devido à sua importância para o desenvolvimento e planejamento urbano da região.

# %%
import pandas as pd

url = "http://dados.recife.pe.gov.br/dataset/e2bd8f0b-1d62-4323-8159-8ebd6ed9eb4a/resource/77c885c4-76ca-45eb-9209-06c5d217122d/download/licenciamento_urbanistico.csv"

data = pd.read_csv(url, sep=';')

# %%
data
# Out:
#       ﻿areatotalconstruida                                assunto  \
# 0                      100           APROVACAO DE PROJETO INICIAL
# 1                      NaN                           OBRA DE ARTE
# 2                      NaN                           OBRA DE ARTE
# 3                       50           APROVACAO DE PROJETO INICIAL
# 4                      100           APROVACAO DE PROJETO INICIAL
# ...                    ...                                    ...
# 74962                  NaN  ALVARA DE LOCALIZACAO E FUNCIONAMENTO
# 74963                  NaN  ALVARA DE LOCALIZACAO E FUNCIONAMENTO
# 74964               190,52           APROVACAO DE PROJETO INICIAL
# 74965                  NaN  ALVARA DE LOCALIZACAO E FUNCIONAMENTO
# 74966                  NaN  ALVARA DE LOCALIZACAO E FUNCIONAMENTO
#
#                  bairro categoria_empreendimento          cnpj data_conclusao  \
# 0                AREIAS                     Obra  2.088921e+13     2017-05-29
# ...
