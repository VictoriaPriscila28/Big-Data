# %% [markdown]
# #### Esta parte é destinada a criação de um dicionario das variaveis utilizadas no arquivo trabalho2.ipynb

# %%
# Dicionário de dados
dicionario_dados = {
    'data_entrada': {
        'tipo': 'data',
        'descricao': 'Data de entrada do processo de licenciamento.'
    },
    'data_saida': {
        'tipo': 'data',
        'descricao': 'Data de saída do processo de licenciamento.'
    },
    'data_pagamento': {
        'tipo': 'data',
        'descricao': 'Data de pagamento da taxa relacionada ao licenciamento.'
    },
    'data_validade_licenca': {
        'tipo': 'data',
        'descricao': 'Data de validade da licença emitida.'
    },
    'dsqfl': {
        'tipo': 'categórico',
        'descricao': 'Descrição da qualidade do licenciamento.'
    },
    'empreendimento_de_impacto': {
        'tipo': 'categórico',
        'descricao': 'Indicação se o empreendimento possui impacto.'
    },
    'endereco_empreendimento': {
        'tipo': 'texto',
        'descricao': 'Endereço do empreendimento.'
    },
    'inscricao_mercantil': {
        'tipo': 'texto',
        'descricao': 'Número de inscrição mercantil do empreendimento.'
    },
    'licenciamento_ambiental': {
        'tipo': 'categórico',
        'descricao': 'Indicação se houve licenciamento ambiental.'
    },
    'licenciamento_sanitario': {
        'tipo': 'categórico',
        'descricao': 'Indicação se houve licenciamento sanitário.'
    },
    'licenciamento_urbanistico': {
        'tipo': 'categórico',
        'descricao': 'Indicação se houve licenciamento urbanístico.'
    },
    'razao_social': {
        'tipo': 'texto',
        'descricao': 'Razão social do empreendimento.'
    },
    'razao_social_mercantil': {
        'tipo': 'texto',
        'descricao': 'Razão social mercantil do empreendimento.'
    },
    'num_licenca': {
        'tipo': 'texto',
        'descricao': 'Número da licença emitida.'
    },
    'num_processo': {
        'tipo': 'texto',
        'descricao': 'Número do processo de licenciamento.'
    },
    'porte_empreendimento': {
        'tipo': 'categórico',
        'descricao': 'Porte do empreendimento.'
    },
    'potencial_empreendimento': {
        'tipo': 'categórico',
        'descricao': 'Potencial do empreendimento.'
    },
    'processo_automatizado': {
        'tipo': 'categórico',
        'descricao': 'Indicação se o processo foi automatizado.'
    },
    'situacao_processo': {
        'tipo': 'categórico',
        'descricao': 'Situação atual do processo de licenciamento.'
    },
    'tipo_mercantil': {
        'tipo': 'categórico',
        'descricao': 'Tipo mercantil do empreendimento.'
    },
    'tipo_processo': {
        'tipo': 'categórico',
        'descricao': 'Tipo do processo de licenciamento.'
    },
    'tipo_proc_licenciamento': {
        'tipo': 'categórico',
        'descricao': 'Tipo do procedimento de licenciamento.'
    },
    'uso_imovel': {
        'tipo': 'categórico',
        'descricao': 'Uso do imóvel.'
    },
    'valor_taxa': {
        'tipo': 'numérico',
        'descricao': 'Valor da taxa de licenciamento.'
    },
    'valor_pago': {
        'tipo': 'numérico',
        'descricao': 'Valor pago no processo de licenciamento.'
    },
    'latitude': {
        'tipo': 'numérico',
        'descricao': 'Latitude do empreendimento.'
    },
    'longitude': {
        'tipo': 'numérico',
        'descricao': 'Longitude do empreendimento.'
    }
}
